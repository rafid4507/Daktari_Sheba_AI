# %%
from langchain import Qdrant
from langchain.embeddings.openai import OpenAIEmbeddings
import os
import qdrant_client
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 from langchain import Qdrant
#       2 from langchain.embeddings.openai import OpenAIEmbeddings
#       3 import os
#
# ImportError: cannot import name 'Qdrant' from 'langchain' (c:\Users\Rafid\anaconda3\envs\ShebaBot\lib\site-packages\langchain\__init__.py)

# %%
def load_pdf(data):
    if os.path.isdir(data):
        # Load all PDFs in a folder
        loader = DirectoryLoader(
            data,
            glob="**/*.pdf",
            loader_cls=PyPDFLoader,
        )
    else:
        # Load a single PDF
        loader = PyPDFLoader(path)

    return loader.load()

# %%
extracted_data = load_pdf(data='data/')

# %%
import os
os.environ["PINECONE_API_KEY"] = os.getenv("PINECONE_API_KEY")

# %%
from qdrant_client import QdrantClient, models

client = QdrantClient(url="https://467903ae-6f85-48f6-bf67-22b072caed59.us-west-1-0.aws.cloud.qdrant.io")

client.create_collection(
    collection_name="daktari_sheba_ai",
    vectors_config=models.VectorParams(size=100, distance=models.Distance.COSINE),
)
# Out:
# C:\Users\Rafid\AppData\Local\Temp\ipykernel_303792\3215132976.py:3: UserWarning: Failed to obtain server version. Unable to check client-server compatibility. Set check_compatibility=False to skip version check.
#   client = QdrantClient(url="https://467903ae-6f85-48f6-bf67-22b072caed59.us-west-1-0.aws.cloud.qdrant.io")
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[60], line 5
#       1 from qdrant_client import QdrantClient, models
#       3 client = QdrantClient(url="https://467903ae-6f85-48f6-bf67-22b072caed59.us-west-1-0.aws.cloud.qdrant.io")
# ----> 5 client.create_collection(
#       6     collection_name="daktari_sheba_ai",
#       7     vectors_config=models.VectorParams(size=100, distance=models.Distance.COSINE),
#       8 )
#
# File c:\Users\Rafid\anaconda3\envs\ShebaBot\lib\site-packages\qdrant_client\qdrant_client.py:2382, in QdrantClient.create_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, strict_mode_config, **kwargs)
#    2332 """Create empty collection with given parameters
#    2333
#    2334 Args:
#    (...)
#    2378     Operation result
#    2379 """
#    2380 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2382 return self._client.create_collection(
#    2383     collection_name=collection_name,
#    2384     vectors_config=vectors_config,
#    2385     shard_number=shard_number,
#    2386     sharding_method=sharding_method,
#    2387     replication_factor=replication_factor,
#    2388     write_consistency_factor=write_consistency_factor,
#    2389     on_disk_payload=on_disk_payload,
#    2390     hnsw_config=hnsw_config,
#    2391     optimizers_config=optimizers_config,
#    2392     wal_config=wal_config,
#    2393     quantization_config=quantization_config,
#    2394     init_from=init_from,
#    2395     timeout=timeout,
#    2396     sparse_vectors_config=sparse_vectors_config,
#    2397     strict_mode_config=strict_mode_config,
#    2398     **kwargs,
#    2399 )
#
# File c:\Users\Rafid\anaconda3\envs\ShebaBot\lib\site-packages\qdrant_client\qdrant_remote.py:2815, in QdrantRemote.create_collection(self, collection_name, vectors_config, shard_number, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, sparse_vectors_config, sharding_method, strict_mode_config, **kwargs)
#    2797     init_from = GrpcToRest.convert_init_from(init_from)
#    2799 create_collection_request = models.CreateCollection(
#    2800     vectors=vectors_config,
#    2801     shard_number=shard_number,
#    (...)
#    2812     strict_mode_config=strict_mode_config,
#    2813 )
# -> 2815 result: Optional[bool] = self.http.collections_api.create_collection(
#    2816     collection_name=collection_name,
#    2817     create_collection=create_collection_request,
#    2818     timeout=timeout,
#    2819 ).result
#    2821 assert result is not None, "Create collection returned None"
#    2822 return result
#
# File c:\Users\Rafid\anaconda3\envs\ShebaBot\lib\site-packages\qdrant_client\http\api\collections_api.py:294, in SyncCollectionsApi.create_collection(self, collection_name, timeout, create_collection)
#     285 def create_collection(
#     286     self,
#     287     collection_name: str,
#     288     timeout: int = None,
#     289     create_collection: m.CreateCollection = None,
#     290 ) -> m.InlineResponse200:
#     291     """
#     292     Create new collection with given parameters
#     293     """
# --> 294     return self._build_for_create_collection(
#     295         collection_name=collection_name,
#     296         timeout=timeout,
#     297         create_collection=create_collection,
#     298     )
#
# File c:\Users\Rafid\anaconda3\envs\ShebaBot\lib\site-packages\qdrant_client\http\api\collections_api.py:96, in _CollectionsApi._build_for_create_collection(self, collection_name, timeout, create_collection)
#      94 if "Content-Type" not in headers:
#      95     headers["Content-Type"] = "application/json"
# ---> 96 return self.api_client.request(
#      97     type_=m.InlineResponse200,
#      98     method="PUT",
#      99     url="/collections/{collection_name}",
#     100     headers=headers if headers else None,
#     101     path_params=path_params,
#     102     params=query_params,
#     103     content=body,
#     104 )
#
# File c:\Users\Rafid\anaconda3\envs\ShebaBot\lib\site-packages\qdrant_client\http\api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File c:\Users\Rafid\anaconda3\envs\ShebaBot\lib\site-packages\qdrant_client\http\api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 403 (Forbidden)
# Raw response content:
# b'{"error":"forbidden"}'
